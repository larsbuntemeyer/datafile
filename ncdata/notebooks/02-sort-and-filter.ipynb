# %% [markdown]
# # Working with Datafiles

# %% [markdown]
# Let's import the FileReport class.

# %%
from PyDatSci.FileReport import FileReport
import PyDatSci.FileReport as fr
import pickle

# %% [markdown]
# Let's read the file report we created in the `FileReport` notebook:

# %%
report = FileReport.read('/work/ch0636/eddy/pool/sims/cmip5/file-report-cmip5.fr')
print(report)
# Out:
# FileReport of /work/ch0636/eddy/pool/sims/cmip5
#
#  Number of Files               : 12034
#  Number of valid Files         : 12031
#  Number of Symlinks            : 0
#  Number of missing Symlinks    : 3
#
#  Number of Suffixes            : 11
#                .status         : 2
#                .nc             : 11902
#                .py             : 59
#                .p              : 9
#                .txt            : 16
#                .csv            : 2
#                .png            : 31
#                .sh             : 2
#                .csv#           : 2
#                no suffix       : 1
#                .gr             : 5

# %% [markdown]
# ## Scan for NetCDF attributes

# %% [markdown]
# The `FileReport` acutally only contains huge lists of filenames. In the next step, we want to investigate NetCDF files. For this, we use the `DataFile` class. This is basically a container which stores some meta information of the actual file and it's NetCDF attributes, so we can easily access and store them later. To fill this container, we have to scan the NetCDF files from our `FileReport`. This might take some time (especially from a Python Notebook!), but it has to be done just once. So, if it takes to much time, you can skip this step and directly continue the `Sorting` session by reading a pickle dump which i prepared for `CMIP5`.

# %%
datafiles = fr.scan_ncattrs(report['.nc'])
# Out:
# Scanning for NetCDF Attributes...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %% [markdown]
# We quickly dump the datafiles list which now contains NetCDF attributes to a file.

# %%
pickle.dump(datafiles, open('/work/ch0636/eddy/pool/sims/cmip5/datafiles-cmip5','wb'))

# %% [markdown]
# ## Sorting

# %% [markdown]
# Reload our datafiles:

# %%
datafiles = pickle.load(open('/work/ch0636/eddy/pool/sims/cmip5/datafiles-cmip5','rb'))

# %% [markdown]
# We can create a dictionary containing an arbitray sorting order for the datafiles, e.g.:

# %%
sorted_files = fr.sort_by_attrs(datafiles, ['institute_id'])

# %% [markdown]
# There is a little helper routine which can print this dictionarys keys a little nice, so let's import is, and see what we found.

# %%
from PyDatSci.tools import print_dict
print_dict(sorted_files)
# Out:
# -> NASA-GISS
# -> ICHEC
# -> NSF-DOE-NCAR
# -> MIROC
# -> NOAA GFDL
# -> BNU
# -> MOHC
# -> BCC
# -> CSIRO-BOM
# -> no institute_id
# -> MRI
# -> NCC
# -> IPSL
# -> INM
# -> CNRM-CERFACS
# -> NCAR
# -> LASG-CESS
# -> CMCC
# -> CSIRO-QCCCE
# -> CCCma
# -> MPI-M

# %% [markdown]
# Ok, there are files without an `institute_id`! Let's check them out:

# %%
for datafile in sorted_files['no institute_id']:
    print(datafile)
# Out:
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2083.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2070.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2075.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/maxFile_TColdP_2095.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2076.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2065.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/maxFile_TColdP_2092.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2092.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2079.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2071.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2072.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2067.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2088.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2084.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2064.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2091.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2085.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2081.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2086.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2069.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2066.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2087.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2082.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2074.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2068.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2077.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/maxFile_TColdP_2091.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2078.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2073.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2089.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2080.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPCC-AR5-SLR-DATA/total-ens-slr-45-5.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPCC-AR5-SLR-DATA/total-ens-slr-85-5.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPCC-AR5-SLR-DATA/total-ens-slr-26-5.nc

# %% [markdown]
# These are obviously no files that are supposed to conform with cmor standard.

# %% [markdown]
# Let's sort our files a little more accurately, e.g.

# %%
sorted_files = fr.sort_by_attrs(datafiles, ['institute_id','model_id','experiment_id','frequency','varname'])

# %% [markdown]
# The dictionary `sorted_files` now contains all datafiles sorted by a list of NetCDF attributes. To check out it's contents, you can print the dictionary using:

# %%
print_dict(sorted_files)
# Out:
# -> NASA-GISS
# -----> GISS-E2-R
# ---------> rcp45
# -------------> day
# -----------------> tas
# -----------------> tasmin
# -----------------> tasmax
# -----------------> pr
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> tas
# -----------------> tasmin
# -----------------> tasmax
# -----------------> pr
# -> ICHEC
# -----> EC-EARTH
# ---------> rcp85
# -------------> day
# -----------------> prmd
# -----------------> tas
# -----------------> tasmax-mm-ymax
# -----------------> pr
# -----------------> prmd-ymm
# -----------------> psl
# -----------------> tasmax
# -----------------> tasmin
# ---------> rcp45
# -------------> day
# -----------------> prmd
# -----------------> tas
# -----------------> tasmax-mm-ymax
# -----------------> pr
# -----------------> prmd-ymm
# -----------------> psl
# -----------------> tasmax
# -----------------> tasmin
# ---------> rcp26
# -------------> day
# -----------------> tas
# -----------------> pr
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmax-mm-ymax
# -----------------> PDry95P
# -----------------> pr
# -----------------> tas
# -----------------> tasmax
# -----------------> tasmin
# -----------------> PNP95thYWD
# -----------------> prmd
# -----------------> PNP95thY
# -----------------> TColdP
# -----------------> P95thYWD
# -----------------> prmd-ymm
# -----------------> psl
# -> NSF-DOE-NCAR
# -----> CESM1-CAM5
# ---------> rcp85
# -------------> day
# -----------------> prmd
# -----------------> tas
# -----------------> tasmin
# -----------------> pr
# -----------------> prmd-ymm
# -----------------> tasmax
# -----------------> tasmax-mm-ymax
# -----------------> tasmin-mm-ymin
# ---------> rcp45
# -------------> day
# -----------------> prmd
# -----------------> tas
# -----------------> tasmin
# -----------------> pr
# -----------------> prmd-ymm
# -----------------> tasmax
# -----------------> tasmax-mm-ymax
# -----------------> tasmin-mm-ymin
# ---------> rcp26
# -------------> day
# -----------------> prmd
# -----------------> tas
# -----------------> tasmin
# -----------------> pr
# -----------------> prmd-ymm
# -----------------> tasmax
# -----------------> tasmax-mm-ymax
# -----------------> tasmin-mm-ymin
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> PDry95P
# -----------------> pr
# -----------------> tas
# -----------------> tasmax-mm-ymax
# -----------------> PNP95thYWD
# -----------------> prmd
# -----------------> tasmin-mm-ymin
# -----------------> TColdP
# -----------------> P95thYWD
# -----------------> prmd-ymm
# -----------------> tasmax
# -----> CESM1-FASTCHEM
# ---------> historical
# -------------> day
# -----------------> prmd
# -----------------> tas
# -----------------> tasmin
# -----------------> pr
# -----------------> prmd-ymm
# -----------------> psl
# -----------------> tasmax
# -----------------> tasmax-mm-ymax
# -----------------> tasmin-mm-ymin
# -----> CESM1-BGC
# ---------> rcp85
# -------------> day
# -----------------> prmd
# -----------------> tas
# -----------------> tasmin
# -----------------> pr
# -----------------> prmd-ymm
# -----------------> psl
# -----------------> tasmax
# -----------------> tasmax-mm-ymax
# -----------------> tasmin-mm-ymin
# ---------> rcp45
# -------------> day
# -----------------> prmd
# -----------------> tas
# -----------------> tasmin
# -----------------> pr
# -----------------> prmd-ymm
# -----------------> psl
# -----------------> tasmax
# -----------------> tasmax-mm-ymax
# -----------------> tasmin-mm-ymin
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> PDry95P
# -----------------> pr
# -----------------> tas
# -----------------> tasmax
# -----------------> tasmax-mm-ymax
# -----------------> PNP95thYWD
# -----------------> prmd
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thY
# -----------------> TColdP
# -----------------> P95thYWD
# -----------------> prmd-ymm
# -----------------> psl
# -> MIROC
# -----> MIROC-ESM-CHEM
# ---------> rcp85
# -------------> day
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> height
# -----------------> evap
# -----------------> prmd
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> hfls
# -----------------> vas
# -----------------> psl
# -----------------> rlus
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> hus
# -----------------> rsds
# -----------------> uas
# -----------------> sfcWind
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> height
# -----------------> evap
# -----------------> prmd
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> hfls
# -----------------> vas
# -----------------> psl
# -----------------> rlus
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> hus
# -----------------> rsds
# -----------------> uas
# -----------------> sfcWind
# -----------------> tasmax
# ---------> rcp26
# -------------> day
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> height
# -----------------> evap
# -----------------> prmd
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> hfls
# -----------------> vas
# -----------------> psl
# -----------------> rlus
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> hus
# -----------------> rsds
# -----------------> uas
# -----------------> sfcWind
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> height
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> TColdP
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> hfls
# -----------------> vas
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> hus
# -----------------> PDry95P
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# -----> MIROC-ESM
# ---------> rcp85
# -------------> day
# -----------------> prmd
# -----------------> tasmax-mm-ymax
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> psl
# -----------------> height
# -----------------> prmd-ymm
# -----------------> tasmin
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tas
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> hus
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> prmd
# -----------------> tasmax-mm-ymax
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> psl
# -----------------> height
# -----------------> prmd-ymm
# -----------------> tasmin
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tas
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> hus
# -----------------> tasmax
# ---------> rcp26
# -------------> day
# -----------------> prmd
# -----------------> tasmax-mm-ymax
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> psl
# -----------------> height
# -----------------> prmd-ymm
# -----------------> tasmin
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tas
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> height
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> PNP95thY
# -----------------> TColdP
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> prmd
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> tasmax
# -----> MIROC4h
# ---------> rcp45
# -------------> day
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> vas
# -----------------> rlus
# -----------------> rsds
# -----------------> uas
# -----------------> sfcWind
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# -----> MIROC5
# ---------> rcp85
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp26
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> TColdP
# -----------------> ws
# -----------------> hfls
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> hus
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# -> NOAA GFDL
# -----> GFDL-ESM2G
# ---------> rcp85
# -------------> day
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> vas
# -----------------> rlus
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> hfls
# -----------------> average_DT
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> hus
# -----------------> rsds
# -----------------> uas
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> vas
# -----------------> rlus
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> hfls
# -----------------> average_DT
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> hus
# -----------------> rsds
# -----------------> uas
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# ---------> rcp26
# -------------> day
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> vas
# -----------------> rlus
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> hfls
# -----------------> average_DT
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> hus
# -----------------> rsds
# -----------------> uas
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> areacella
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> PNP95thY
# -----------------> TColdP
# -----------------> ws
# -----------------> hfls
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> hus
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> average_DT
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# -----> GFDL-CM3
# ---------> rcp85
# -------------> day
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> vas
# -----------------> rlus
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> hfls
# -----------------> average_DT
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> hus
# -----------------> rsds
# -----------------> uas
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> vas
# -----------------> tasmin
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> psl
# -----------------> tasmax-mm-ymax
# -----------------> hus
# -----------------> prmd
# -----------------> tas
# -----------------> uas
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> sfcWind
# -----------------> average_DT
# -----------------> tasmax
# ---------> rcp26
# -------------> day
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> vas
# -----------------> rlus
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> hfls
# -----------------> average_DT
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> hus
# -----------------> rsds
# -----------------> uas
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> areacella
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> TColdP
# -----------------> ws
# -----------------> hfls
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> average_DT
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> hus
# -----------------> runoff
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# -----> GFDL-ESM2M
# ---------> rcp85
# -------------> day
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> vas
# -----------------> rlus
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> hfls
# -----------------> average_DT
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> hus
# -----------------> rsds
# -----------------> uas
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> vas
# -----------------> rlus
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> hfls
# -----------------> average_DT
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> hus
# -----------------> rsds
# -----------------> uas
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# ---------> rcp26
# -------------> day
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> vas
# -----------------> rlus
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> hfls
# -----------------> average_DT
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> hus
# -----------------> rsds
# -----------------> uas
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> areacella
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> TColdP
# -----------------> ws
# -----------------> hfls
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> hus
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> average_DT
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# -> BNU
# -----> BNU-ESM
# ---------> rcp85
# -------------> day
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> height
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> hfls
# -----------------> hus
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> height
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> hfls
# -----------------> hus
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# ---------> rcp26
# -------------> day
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> height
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> hfls
# -----------------> hus
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> height
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> PNP95thY
# -----------------> TColdP
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> hfls
# -----------------> hus
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> vas
# -----------------> PDry95P
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# -> MOHC
# -----> HadGEM2-ES
# ---------> rcp85
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp26
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> PNP95thY
# -----------------> TColdP
# -----------------> ws
# -----------------> hfls
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# -----> HadCM3
# ---------> rcp45
# -------------> day
# -----------------> tasmin
# -----------------> pr
# -----------------> tas
# -----------------> sfcWind
# -----------------> psl
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -------------> day
# -----------------> prmd
# -----------------> tas
# -----------------> tasmin
# -----------------> pr
# -----------------> prmd-ymm
# -----------------> sfcWind
# -----------------> psl
# -----------------> tasmax
# -----------------> tasmin-mm-ymin
# -----------------> tasmax-mm-ymax
# -----> HadGEM2-CC
# ---------> rcp85
# -------------> day
# -----------------> prmd
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> vas
# -----------------> rlus
# -----------------> tas
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> prmd
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> vas
# -----------------> rlus
# -----------------> tas
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> PNP95thY
# -----------------> TColdP
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> psl
# -----------------> prmd
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> sfcWind
# -----------------> tasmax
# -> BCC
# -----> bcc-csm1-1-m
# ---------> rcp85
# -------------> day
# -----------------> prmd
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> vas
# -----------------> rlus
# -----------------> tas
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> prmd
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> vas
# -----------------> rlus
# -----------------> tas
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> tasmax
# ---------> rcp26
# -------------> day
# -----------------> prmd
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> vas
# -----------------> rlus
# -----------------> tas
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> tasmax
# ---------> historical
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> PNP95thY
# -----------------> TColdP
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> psl
# -----------------> prmd
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> tasmax
# -----> bcc-csm1-1
# ---------> rcp85
# -------------> day
# -----------------> prmd
# -----------------> tasmax-mm-ymax
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> psl
# -----------------> height
# -----------------> prmd-ymm
# -----------------> tasmin
# -----------------> vas
# -----------------> rlus
# -----------------> tas
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> prmd
# -----------------> tasmax-mm-ymax
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> psl
# -----------------> height
# -----------------> prmd-ymm
# -----------------> tasmin
# -----------------> vas
# -----------------> rlus
# -----------------> tas
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> tasmax
# ---------> rcp26
# -------------> day
# -----------------> prmd
# -----------------> tasmax-mm-ymax
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> psl
# -----------------> height
# -----------------> prmd-ymm
# -----------------> tasmin
# -----------------> vas
# -----------------> rlus
# -----------------> tas
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> PNP95thY
# -----------------> TColdP
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> psl
# -----------------> prmd
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> tasmax
# -> CSIRO-BOM
# -----> ACCESS1.3
# ---------> rcp85
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> piControl
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# ---------> historical
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> PNP95thY
# -----------------> TColdP
# -----------------> ws
# -----------------> hfls
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> hus
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# -----> ACCESS1-0
# ---------> rcp85
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> historicalExt
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# ---------> historical
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> PNP95thY
# -----------------> TColdP
# -----------------> ws
# -----------------> hfls
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> hus
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# -> no institute_id
# -----> no model_id
# ---------> no experiment_id
# -------------> no frequency
# -----------------> no varname
# -----------------> modelname
# -> MRI
# -----> MRI-CGCM3
# ---------> rcp85
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp26
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> TColdP
# -----------------> ws
# -----------------> hfls
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> hus
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# -----> MRI-ESM1
# ---------> rcp85
# -------------> day
# -----------------> prmd
# -----------------> tas
# -----------------> tasmin
# -----------------> pr
# -----------------> prmd-ymm
# -----------------> tasmax
# -----------------> tasmax-mm-ymax
# -----------------> tasmin-mm-ymin
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> TColdP
# -----------------> ws
# -----------------> hfls
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> hus
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# -> NCC
# -----> NorESM1-M
# ---------> rcp85
# -------------> day
# -----------------> prmd
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> tasmax
# -----------------> tasmax-mm-ymax
# -----------------> rlus
# -----------------> rsds
# -----------------> prmd-ymm
# -----------------> tas
# -----------------> psl
# ---------> rcp45
# -------------> day
# -----------------> prmd
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> vas
# -----------------> rlus
# -----------------> tas
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> hus
# -----------------> tasmax
# ---------> rcp26
# -------------> day
# -----------------> prmd
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> tasmax
# -----------------> tasmax-mm-ymax
# -----------------> rlus
# -----------------> rsds
# -----------------> prmd-ymm
# -----------------> tas
# -----------------> psl
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> PDry95P
# -----------------> pr
# -----------------> tas
# -----------------> tasmax-mm-ymax
# -----------------> PNP95thYWD
# -----------------> prmd
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thY
# -----------------> TColdP
# -----------------> P95thYWD
# -----------------> prmd-ymm
# -----------------> tasmax
# -> IPSL
# -----> IPSL-CM5A-MR
# ---------> rcp85
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp26
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> TColdP
# -----------------> ws
# -----------------> hfls
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> hus
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# -----> IPSL-CM5A-LR
# ---------> rcp85
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp26
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> TColdP
# -----------------> ws
# -----------------> hfls
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> hus
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# -----> IPSL-CM5B-LR
# ---------> rcp85
# -------------> day
# -----------------> prmd
# -----------------> tasmax-mm-ymax
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> psl
# -----------------> height
# -----------------> prmd-ymm
# -----------------> tasmin
# -----------------> vas
# -----------------> rlus
# -----------------> tas
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> prmd
# -----------------> tasmax-mm-ymax
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> psl
# -----------------> height
# -----------------> prmd-ymm
# -----------------> tasmin
# -----------------> vas
# -----------------> rlus
# -----------------> tas
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> height
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> PNP95thY
# -----------------> TColdP
# -----------------> ws
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> psl
# -----------------> prmd
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> sfcWind
# -----------------> tasmax
# -> INM
# -----> inmcm4
# ---------> rcp85
# -------------> day
# -----------------> prmd
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# ...
# -----------------> tas
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> sfcWind
# -----------------> tasmax
# -----> CMCC-CESM
# ---------> rcp85
# -------------> day
# -----------------> prmd
# -----------------> tas
# -----------------> tasmin
# -----------------> pr
# -----------------> prmd-ymm
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> PDry95P
# -----------------> pr
# -----------------> tas
# -----------------> tasmax-mm-ymax
# -----------------> PNP95thYWD
# -----------------> prmd
# -----------------> tasmin-mm-ymin
# -----------------> TColdP
# -----------------> P95thYWD
# -----------------> prmd-ymm
# -----------------> tasmax
# -> CSIRO-QCCCE
# -----> CSIRO-Mk3-6-0
# ---------> rcp85
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp26
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> TColdP
# -----------------> ws
# -----------------> hfls
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> hus
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# -> CCCma
# -----> CanESM2
# ---------> rcp85
# -------------> day
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> height
# -----------------> prmd-ymm
# -----------------> tasmin
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> height
# -----------------> prmd-ymm
# -----------------> tasmin
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp26
# -------------> day
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> height
# -----------------> prmd-ymm
# -----------------> tasmin
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> TColdP
# -----------------> ws
# -----------------> hfls
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> hus
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> prmd
# -----------------> tasmax
# -----> CanCM4
# ---------> rcp45
# -------------> day
# -----------------> tasmin
# -----------------> uas
# -----------------> pr
# -----------------> tasmax
# -----------------> psl
# -----------------> vas
# ---------> historical
# -------------> day
# -----------------> prmd
# -----------------> prmd-ymm
# -----------------> tasmin
# -----------------> uas
# -----------------> ws
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> psl
# -----------------> tasmax
# -----------------> tasmax-mm-ymax
# -----------------> vas
# -> MPI-M
# -----> MPI-ESM-LR
# ---------> rcp85
# -------------> mon
# -----------------> evspsbl
# -----------------> ts
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> prc
# -----------------> tro3
# -----------------> height
# -----------------> co2mass
# -----------------> ap
# -----------------> tauv
# -----------------> rlus
# -----------------> rsdt
# -----------------> clt
# -----------------> rsds
# -----------------> rldscs
# -----------------> cct
# -----------------> cli
# -----------------> hfls
# -----------------> zg
# -----------------> hus
# -----------------> prw
# -----------------> hfss
# -----------------> rsutcs
# -----------------> ua
# -----------------> clwvi
# -----------------> rsdscs
# -----------------> rsut
# -----------------> wap
# -----------------> rsuscs
# -----------------> clivi
# -----------------> prsn
# -----------------> fco2nat
# -----------------> tauu
# -----------------> ps
# -----------------> rtmt
# -----------------> va
# -----------------> rlutcs
# -----------------> rlut
# -----------------> tasmax
# -----------------> hur
# -----------------> ta
# -----------------> psl
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp45
# -------------> mon
# -----------------> evspsbl
# -----------------> fco2nat
# -----------------> hfss
# -----------------> rlds
# -----------------> pr
# -----------------> prc
# -----------------> tro3
# -----------------> height
# -----------------> co2mass
# -----------------> ap
# -----------------> rlut
# -----------------> rlus
# -----------------> rsdt
# -----------------> clt
# -----------------> rtmt
# -----------------> rsus
# -----------------> rldscs
# -----------------> cct
# -----------------> cli
# -----------------> hfls
# -----------------> zg
# -----------------> hus
# -----------------> psl
# -----------------> rsutcs
# -----------------> ua
# -----------------> clwvi
# -----------------> rsut
# -----------------> wap
# -----------------> rsuscs
# -----------------> clivi
# -----------------> prsn
# -----------------> ts
# -----------------> tauu
# -----------------> ps
# -----------------> rsds
# -----------------> va
# -----------------> prw
# -----------------> rlutcs
# -----------------> rsdscs
# -----------------> tauv
# -----------------> tasmax
# -----------------> hur
# -----------------> ta
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp26
# -------------> mon
# -----------------> evspsbl
# -----------------> fco2nat
# -----------------> hfss
# -----------------> rlds
# -----------------> pr
# -----------------> prc
# -----------------> tro3
# -----------------> height
# -----------------> co2mass
# -----------------> ap
# -----------------> rlut
# -----------------> rlus
# -----------------> rsdt
# -----------------> clt
# -----------------> rldscs
# -----------------> cct
# -----------------> cli
# -----------------> rsus
# -----------------> zg
# -----------------> hus
# -----------------> hfls
# -----------------> rsutcs
# -----------------> va
# -----------------> ua
# -----------------> clwvi
# -----------------> rsut
# -----------------> wap
# -----------------> rsuscs
# -----------------> psl
# -----------------> prsn
# -----------------> ts
# -----------------> tauu
# -----------------> ps
# -----------------> rsds
# -----------------> rlutcs
# -----------------> prw
# -----------------> rtmt
# -----------------> rsdscs
# -----------------> clivi
# -----------------> tauv
# -----------------> tasmax
# -----------------> hur
# -----------------> ta
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> historical
# -------------> mon
# -----------------> evspsbl
# -----------------> fco2nat
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> prc
# -----------------> hur
# -----------------> height
# -----------------> co2mass
# -----------------> ap
# -----------------> rsdt
# -----------------> rlus
# -----------------> clt
# -----------------> rldscs
# -----------------> cct
# -----------------> cli
# -----------------> hfls
# -----------------> zg
# -----------------> hus
# -----------------> psl
# -----------------> rlut
# -----------------> hfss
# -----------------> rsutcs
# -----------------> ua
# -----------------> clwvi
# -----------------> rsut
# -----------------> wap
# -----------------> rsuscs
# -----------------> clivi
# -----------------> prsn
# -----------------> ts
# -----------------> tauu
# -----------------> ps
# -----------------> rlutcs
# -----------------> rsds
# -----------------> va
# -----------------> prw
# -----------------> rtmt
# -----------------> rsdscs
# -----------------> tauv
# -----------------> tasmax
# -----------------> tro3
# -----------------> ta
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> TColdP
# -----------------> ws
# -----------------> hfls
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> hus
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax
# -----> MPI-ESM-P
# ---------> historical
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> rsds
# -----------------> uas
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# -----> MPI-ESM-MR
# ---------> rcp85
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp45
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> rcp26
# -------------> day
# -----------------> evap
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tas
# -----------------> psl
# -----------------> prmd-ymm
# -----------------> tasmax-mm-ymax
# -----------------> runoff
# -----------------> vas
# -----------------> rlus
# -----------------> tasmin-mm-ymin
# -----------------> uas
# -----------------> ws
# -----------------> rsds
# -----------------> sfcWind
# -----------------> prmd
# -----------------> hfls
# -----------------> hus
# -----------------> tasmax
# ---------> historical
# -------------> fx
# -----------------> sftlf
# -----------------> orog
# -------------> day
# -----------------> TWarmP
# -----------------> tasmin
# -----------------> rsus
# -----------------> rlds
# -----------------> pr
# -----------------> tasmin-mm-ymin
# -----------------> PNP95thYWD
# -----------------> rlus
# -----------------> PNP95thY
# -----------------> TColdP
# -----------------> ws
# -----------------> hfls
# -----------------> prmd-ymm
# -----------------> PDry95P
# -----------------> hus
# -----------------> psl
# -----------------> evap
# -----------------> tasmax-mm-ymax
# -----------------> tas
# -----------------> runoff
# -----------------> vas
# -----------------> rsds
# -----------------> uas
# -----------------> P95thYWD
# -----------------> prmd
# -----------------> sfcWind
# -----------------> tasmax

# %% [markdown]
# You can see, that this gives an overview of the available files depending on their NetCDF attributes that we defined above. Another way, to walk through the dictionary, is to check out the keys of the recursive dictionary:

# %% [markdown]
# Check out what `institude_id`s are available:

# %%
print(sorted_files.keys())
# Out:
# dict_keys(['NASA-GISS', 'ICHEC', 'NSF-DOE-NCAR', 'MIROC', 'NOAA GFDL', 'BNU', 'MOHC', 'BCC', 'CSIRO-BOM', 'no institute_id', 'MRI', 'NCC', 'IPSL', 'INM', 'CNRM-CERFACS', 'NCAR', 'LASG-CESS', 'CMCC', 'CSIRO-QCCCE', 'CCCma', 'MPI-M'])

# %% [markdown]
# Assume we are interested in the files with `institute_id='MPI-ESM'`. Let's see what kind of `model_id`s we get:

# %%
print(sorted_files['MPI-M'].keys())
# Out:
# dict_keys(['MPI-ESM-LR', 'MPI-ESM-P', 'MPI-ESM-MR'])

# %% [markdown]
# ... and so on ...

# %%
print(sorted_files['MPI-M']['MPI-ESM-LR'].keys())
# Out:
# dict_keys(['rcp85', 'rcp45', 'rcp26', 'historical'])

# %%
print(sorted_files['MPI-M']['MPI-ESM-LR']['historical'].keys())
# Out:
# dict_keys(['mon', 'fx', 'day'])

# %%
print(sorted_files['MPI-M']['MPI-ESM-LR']['historical']['day'].keys())
# Out:
# dict_keys(['TWarmP', 'tasmin', 'rsus', 'rlds', 'pr', 'tasmin-mm-ymin', 'PNP95thYWD', 'rlus', 'TColdP', 'ws', 'hfls', 'prmd-ymm', 'PDry95P', 'hus', 'psl', 'evap', 'tasmax-mm-ymax', 'tas', 'runoff', 'vas', 'rsds', 'uas', 'P95thYWD', 'prmd', 'sfcWind', 'tasmax'])

# %% [markdown]
# Now, let's see what the dictionary actually contains for us:

# %%
print(sorted_files['MPI-M']['MPI-ESM-LR']['historical']['day']['pr'])
# Out:
# [<PyDatSci.DataFile.DataFile object at 0x2adac252d278>, <PyDatSci.DataFile.DataFile object at 0x2adac741fbe0>, <PyDatSci.DataFile.DataFile object at 0x2adac9eae860>]

# %% [markdown]
# We can see that the file list contains objects of type `DataFile`. This is basically a container which stores some meta information of the actual file and it's NetCDF attributes. Let's print the filenames:

# %%
for datafile in sorted_files['MPI-M']['MPI-ESM-LR']['historical']['day']['pr']:
    print(datafile.filename)
# Out:
# /work/ch0636/eddy/pool/sims/cmip5/MPI-ESM-LR/day/pr/pr_day_MPI-ESM-LR_historical_r1i1p1_18500101-20051231.nc
# /work/ch0636/eddy/pool/sims/cmip5/MPI-ESM-LR/year/pr/pr_year_MPI-ESM-LR_historical_r1i1p1_18500101-20051231.nc
# /work/ch0636/eddy/pool/sims/cmip5/MPI-ESM-LR/mon/pr/pr_mon_MPI-ESM-LR_historical_r1i1p1_18500101-20051231.nc

# %% [markdown]
# We can recognize, that `pr_mon_MPI-ESM-LR_historical_r1i1p1_18500101-20051231.nc` and `pr_year_MPI-ESM-LR_historical_r1i1p1_18500101-20051231.nc` actually have inconsistent netcdf attributes and filenames. Their filenames indicate different frequencies than the NetCDF attribute in the file.

# %% [markdown]
# We can check this, since we stored the NetCDF attributes in the `DataFile` container, e.g.

# %%
for datafile in sorted_files['MPI-M']['MPI-ESM-LR']['historical']['day']['pr']:
    print(datafile.filename)
    print(datafile.frequency)
# Out:
# /work/ch0636/eddy/pool/sims/cmip5/MPI-ESM-LR/day/pr/pr_day_MPI-ESM-LR_historical_r1i1p1_18500101-20051231.nc
# day
# /work/ch0636/eddy/pool/sims/cmip5/MPI-ESM-LR/year/pr/pr_year_MPI-ESM-LR_historical_r1i1p1_18500101-20051231.nc
# day
# /work/ch0636/eddy/pool/sims/cmip5/MPI-ESM-LR/mon/pr/pr_mon_MPI-ESM-LR_historical_r1i1p1_18500101-20051231.nc
# day

# %% [markdown]
# So we see that these files, in fact, have inconsistencies. Let's check out the history of the file:

# %%
yearly_file = sorted_files['MPI-M']['MPI-ESM-LR']['historical']['day']['pr'][0]
print(yearly_file.history)
# Out:
# Wed May 07 17:17:57 2014: cdo mergetime pr_day_MPI-ESM-LR_historical_r1i1p1_18500101-18591231.nc pr_day_MPI-ESM-LR_historical_r1i1p1_18600101-18691231.nc pr_day_MPI-ESM-LR_historical_r1i1p1_18700101-18791231.nc pr_day_MPI-ESM-LR_historical_r1i1p1_18800101-18891231.nc pr_day_MPI-ESM-LR_historical_r1i1p1_18900101-18991231.nc pr_day_MPI-ESM-LR_historical_r1i1p1_19000101-19091231.nc pr_day_MPI-ESM-LR_historical_r1i1p1_19100101-19191231.nc pr_day_MPI-ESM-LR_historical_r1i1p1_19200101-19291231.nc pr_day_MPI-ESM-LR_historical_r1i1p1_19300101-19391231.nc pr_day_MPI-ESM-LR_historical_r1i1p1_19400101-19491231.nc pr_day_MPI-ESM-LR_historical_r1i1p1_19500101-19591231.nc pr_day_MPI-ESM-LR_historical_r1i1p1_19600101-19691231.nc pr_day_MPI-ESM-LR_historical_r1i1p1_19700101-19791231.nc pr_day_MPI-ESM-LR_historical_r1i1p1_19800101-19891231.nc pr_day_MPI-ESM-LR_historical_r1i1p1_19900101-19991231.nc pr_day_MPI-ESM-LR_historical_r1i1p1_20000101-20051231.nc cat/pr_day_MPI-ESM-LR_historical_r1i1p1_18500101-20051231.nc
# Model raw output postprocessing with modelling environment (IMDI) at DKRZ: URL: http://svn-mad.zmaw.de/svn/mad/Model/IMDI/trunk, REV: 3185 2011-05-28T08:46:10Z CMOR rewrote data to comply with CF standards and CMIP5 requirements.

# %% [markdown]
# The `yearly_file` is the result from several cdo commands, that created yearly mean data from a daily input frequency and inherited the attribute `frequency=day` from those. This might become a problem, if we want to filter data files. So let's check this out! We will now walk through the whole datafile list and check if we don't find the frequency in the filename:

# %%
# the lists in which we collect some inconsistent
inconsistent_freq  = []
missing_freq       = []
# now let's loop through the datafiles list (containing all CMIP5 datafiles).
for datafile in datafiles:
    # if the datafile has a frequency attribute, we'll check if
    # it's found in the filename or path.
    if hasattr(datafile,'frequency'):
        if datafile.frequency not in datafile.filename_str:
            inconsistent_freq.append(datafile)
    # we also collect datafiles that have no frequency attribute at all.
    else:
        missing_freq.append(datafile)

print('number of files without frequency: {}'.format(len(missing_freq)))
print('number of files with inconsistent frequency: {}'.format(len(inconsistent_freq)))
# Out:
# number of files without frequency: 34
# number of files with inconsistent frequency: 3768

# %% [markdown]
# We'll have a look at the files that have no frequency attribute:

# %%
for datafile in missing_freq:
    print(datafile)
# Out:
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2083.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2070.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2075.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/maxFile_TColdP_2095.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2076.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2065.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/maxFile_TColdP_2092.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2092.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2079.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2071.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2072.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2067.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2088.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2084.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2064.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2091.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2085.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2081.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2086.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2069.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2066.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2087.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2082.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2074.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2068.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2077.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/maxFile_TColdP_2091.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2078.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2073.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2089.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPSL-CM5A-MR/day/TColdP/minFile_TColdP_2080.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPCC-AR5-SLR-DATA/total-ens-slr-45-5.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPCC-AR5-SLR-DATA/total-ens-slr-85-5.nc
# /work/ch0636/eddy/pool/sims/cmip5/IPCC-AR5-SLR-DATA/total-ens-slr-26-5.nc

# %% [markdown]
# Here they are again, some files that are probably not supposed to conform cmor standard. By the way, all attributes of a file are contained in a dictionary, that you can access by:

# %%
print(missing_freq[0].ncdict.keys())
# Out:
# dict_keys(['Conventions', 'history', 'CDI'])

# %% [markdown]
# It seems that these are just some temporay files, so we will ignore them for now. It's more interesting to look at those files that have inconsistencies in their frequency. We collected them earlier, but there were quite a lot...

# %%
print(len(inconsistent_freq))
# Out:
# 3768

# %% [markdown]
# It's no use to look at that many filenames, so let's sort them again, maybe by frequency and variable name...

# %%
sorted_inconsistent_freq_dict = fr.sort_by_attrs(inconsistent_freq, ['frequency','varname'])
print_dict(sorted_inconsistent_freq_dict)
# Out:
# -> day
# -----> TWarmP
# -----> tasmin
# -----> rsus
# -----> rlds
# -----> pr
# -----> tasmin-mm-ymin
# -----> PNP95thYWD
# -----> rlus
# -----> TColdP
# -----> ws
# -----> PDry95P
# -----> hus
# -----> psl
# -----> evap
# -----> tasmax-mm-ymax
# -----> tas
# -----> runoff
# -----> vas
# -----> rsds
# -----> uas
# -----> P95thYWD
# -----> average_DT
# -----> prmd
# -----> sfcWind
# -----> tasmax

# %% [markdown]
# We see that the inconsistencies are only in the `day` frequency. Let's see, how many files we find for `pr`:

# %%
print(len(sorted_inconsistent_freq_dict['day']['pr']))
# Out:
# 253

# %% [markdown]
# Hmm, still quite a lot. It's time for a filter! Instead of sorting files, we can also filter them by any number of attributes using the `filter_by_attrs` function in the `FileReport` module:

# %%
inconsistent_freq_mpi_pr = fr.filter_by_attrs(sorted_inconsistent_freq_dict['day']['pr'], model_id='MPI-ESM-LR')
print(len(inconsistent_freq_mpi_pr))
# Out:
# 8

# %% [markdown]
# Ok, that seems fine. Let's have a look.

# %%
for datafile in inconsistent_freq_mpi_pr:
    print(datafile)
    print(datafile.frequency)
# Out:
# /work/ch0636/eddy/pool/sims/cmip5/MPI-ESM-LR/year/pr/pr_year_MPI-ESM-LR_rcp26_r1i1p1_20060101-23001231.nc
# day
# /work/ch0636/eddy/pool/sims/cmip5/MPI-ESM-LR/year/pr/pr_year_MPI-ESM-LR_historical_r1i1p1_18500101-20051231.nc
# day
# /work/ch0636/eddy/pool/sims/cmip5/MPI-ESM-LR/year/pr/pr_year_MPI-ESM-LR_rcp45_r1i1p1_20060101-23001231.nc
# day
# /work/ch0636/eddy/pool/sims/cmip5/MPI-ESM-LR/year/pr/pr_year_MPI-ESM-LR_rcp85_r1i1p1_20060101-23001231.nc
# day
# /work/ch0636/eddy/pool/sims/cmip5/MPI-ESM-LR/mon/pr/pr_mon_MPI-ESM-LR_historical_r1i1p1_18500101-20051231.nc
# day
# /work/ch0636/eddy/pool/sims/cmip5/MPI-ESM-LR/mon/pr/pr_mon_MPI-ESM-LR_rcp45_r1i1p1_20060101-23001231.nc
# day
# /work/ch0636/eddy/pool/sims/cmip5/MPI-ESM-LR/mon/pr/pr_mon_MPI-ESM-LR_rcp26_r1i1p1_20060101-23001231.nc
# day
# /work/ch0636/eddy/pool/sims/cmip5/MPI-ESM-LR/mon/pr/pr_mon_MPI-ESM-LR_rcp85_r1i1p1_20060101-23001231.nc
# day

# %% [markdown]
# We can see what we investigated earlier. There are some files, that have inconsistencies between file or pathnames and NetCDF attributes. This might be a problem, if we want to use the `DataFile` class relying on `NetCDF` attributes. We could also, of course, draw meta information from the filename, but that seems insecure,  if we have to rely on a certain file naming convention.
# This was an example of how you can do some checks, investigation and quality management using sorting and filtering with the `DataFile` class. As quickly as you can find some inconsistencies and check stuff, as quickly you could now correct them!

# %% [markdown]
# ## Filtering

# %% [markdown]
# The sorting gives a good overview, of what data is available, like when you sort your books by author, title, genre, etc.. On the other hand, definining a filter and apply it on the datafiles can give you powerful direct access to what you want, e.g.,

# %%
attr_filter = {'institute_id':'MPI-M', 'model_id':'MPI-ESM-LR', 'experiment_id':'historical', 'frequency':'day', 'varname':'pr'}
filtered = fr.filter_by_attrs(datafiles, **attr_filter)

# %% [markdown]
# which will results in the same list of files as above:

# %%
for datafile in filtered:
    print(datafile.filename)
# Out:
# /work/ch0636/eddy/pool/sims/cmip5/MPI-ESM-LR/day/pr/pr_day_MPI-ESM-LR_historical_r1i1p1_18500101-20051231.nc
# /work/ch0636/eddy/pool/sims/cmip5/MPI-ESM-LR/year/pr/pr_year_MPI-ESM-LR_historical_r1i1p1_18500101-20051231.nc
# /work/ch0636/eddy/pool/sims/cmip5/MPI-ESM-LR/mon/pr/pr_mon_MPI-ESM-LR_historical_r1i1p1_18500101-20051231.nc

# %% [markdown]
# Let's see if there is any data from GERICS!

# %%
gerics_files = fr.filter_by_attrs(datafiles, institute_id='GERICS')

# %%
print(gerics_files)
# Out:
# []

# %% [markdown]
# Obviously not in `CMIP5`! :(
